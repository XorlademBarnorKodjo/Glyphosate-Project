# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_excel("DataWithSomeReformatting3.xlsx")
data
# Out:
#      Unnamed: 0                                      Article_title  \
# 0           419  Distribution of glyphosate and aminomethylphos...
# 1           293  The association between coronary artery diseas...
# 2           105  Neurotoxicological effects of the herbicide gl...
# 3           169  Effect of Acute Toxicityof Glyphosate in Gold ...
# 4           379  Comparative toxicity of methidathion and glyph...
# ..          ...                                                ...
# 498         172  Behavior of Five Sulfonylurea Herbicides and a...
# 499           5  Effects of Soil Phosphorus Status on Environme...
# 500         325  Mucosal-associated invariant T-Cell (MAIT) act...
# 501          46  Estimating maternal and prenatal exposure to g...
# 502           8  Final review of the Séralini et al. (2012a) pu...
#
#                                           Article_link  General_outcome  \
# 0      https://doi.org/10.1016/j.scitotenv.2017.10.093                1
# ...

# %%
nations = list(set(data["Loc_experiment"]))
remove_pairs = ["BELGIUM & GERMANY", "ITALY & NETHERLANDS", "CANADA & USA", "UK & USA"]
for pair in remove_pairs:
    nations.remove(pair)
for nation in nations:
    data[nation] = 0
    data[nation][data["Loc_experiment"].str.contains(nation)]=1
data
# Out:
# <ipython-input-3-2cee338bc8f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[nation][data["Loc_experiment"].str.contains(nation)]=1
#      Unnamed: 0                                      Article_title  \
# 0           419  Distribution of glyphosate and aminomethylphos...
# 1           293  The association between coronary artery diseas...
# 2           105  Neurotoxicological effects of the herbicide gl...
# 3           169  Effect of Acute Toxicityof Glyphosate in Gold ...
# 4           379  Comparative toxicity of methidathion and glyph...
# ..          ...                                                ...
# 498         172  Behavior of Five Sulfonylurea Herbicides and a...
# 499           5  Effects of Soil Phosphorus Status on Environme...
# ...

# %%
countries = sorted(nations)
years = sorted(list(set(data["Year"])))

# %%
# show results by country
outcomes_by_country = data.groupby("Loc_experiment").mean()[["General_outcome"]]
outcomes_by_country["num_obs"] = data["Loc_experiment"].value_counts()

# sort by number of observations
outcomes_by_country.sort_values("num_obs", ascending = False)
# Out:
#                      General_outcome  num_obs
# Loc_experiment
# BRAZIL                      0.764706      102
# ARGENTINA                   0.582278       79
# USA                         0.730159       63
# CANADA                      0.733333       30
# FRANCE                      0.833333       24
# CHINA                       0.909091       22
# POLAND                      0.647059       17
# ITALY                       0.750000       16
# GERMANY                     0.800000       15
# INDIA                       0.900000       10
# NIGERIA                     0.625000        8
# TURKEY                      0.625000        8
# COLOMBIA                    0.714286        7
# DENMARK                     0.666667        6
# AUSTRALIA                   0.833333        6
# PORTUGAL                    0.333333        6
# SPAIN                       1.000000        6
# SWITZERLAND                 0.800000        5
# UK                          0.800000        5
# ...

# %%
for country in countries:
    fig, ax = plt.subplots(figsize =(10,10))
    other_countries = [c for c in countries if c != country]
    data.groupby("Year").mean()["General_outcome"].plot.line(color = "k", linewidth = 2, alpha = .3, ax = ax)
    data[data[country] == 1].groupby("Year").mean()["General_outcome"].plot.line(linewidth = 2, ax = ax)
    

#     mean_outcomes[country].plot.line(linewidth = 10, ax = ax)
    for c in other_countries:
        data[data[c] == 1].groupby("Year").mean()["General_outcome"].plot.line(ls = " ", marker = ".", markersize = 5, linewidth = 2, color = "k", alpha = .2, ax = ax)
    plt.title(country)
    plt.show()
    plt.close()

# %%
# show results by country
outcomes_by_Fund_Source = data.groupby("Fund_Source").mean()[["General_outcome"]]
outcomes_by_Fund_Source["num_obs"] = data["Fund_Source"].value_counts()

# sort by number of observations
outcomes_by_Fund_Source.sort_values("num_obs", ascending = False)
# Out:
#                                 General_outcome  num_obs
# Fund_Source
# Public                                 0.734597      211
# None                                   0.684685      111
# Public & University                    0.881579       76
# University                             0.725000       40
# Private                                0.518519       27
# Public & Private                       0.785714       14
# International Org                      0.500000        8
# Private & University                   0.571429        7
# Public & International Org             1.000000        5
# Private & Public                       0.666667        3
# University & International Org         0.000000        1

# %% [markdown]
# # Dr. Caton, I am trying to generate graphs for Funding sources similar to the location of experiment but I keep encountering an error. Please How do I proceed from here.

# %%
Fund_Sources = list(set(data["Fund_Source"]))
#Fund_Source = sorted(Fund_Source)
Fund_Sources
# Out:
# ['Private & Public',
#  'International Org',
#  'Public & University',
#  'Private',
#  'Public & International Org',
#  'Public & Private',
#  'University & International Org',
#  'None',
#  'Public',
#  'Private & University',
#  'University']

# %%
for Fund_Source in Fund_Sources:
    fig, ax = plt.subplots(figsize =(10,10))
    other_Fund_Sources = [c for c in Fund_Sources if c != Fund_Source]
    data.groupby("Year").mean()["General_outcome"].plot.line(color = "k", linewidth = 2, alpha = .3, ax = ax)
    data[data[Fund_Source] == 1].groupby("Year").mean()["General_outcome"].plot.line(linewidth = 2, ax = ax)
    

#     mean_outcomesF.plot.line(linewidth = 10, ax = ax)
    for c in other_Fund_Sources:
        data[data[c] == 1].groupby("Year").mean()["General_outcome"].plot.line(ls = " ", marker = ".", markersize = 5, linewidth = 2, color = "k", alpha = .2, ax = ax)
    plt.title(fund_Source)
    plt.show()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Public & Private'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ce38a137b444> in <module>
# ...

# %%
journals = list(set(data["Journal"]))
years = sorted(list(set(data["Year"])))

# %%
outcomes_by_Journal = data.groupby("Journal").mean()[["General_outcome"]]
outcomes_by_Journal["num_obs"] = data["Journal"].value_counts()
outcomes_by_Journal.sort_values("num_obs", ascending = False)
# Out:
#                                                     General_outcome  num_obs
# Journal
# Ecotoxicology and Environmental Safety                     0.810811       37
# Bulletin of Environmental Contamination and Tox...         0.718750       32
# Environmental Toxicology and Pharmacology                  0.739130       23
# Planta Daninha                                             0.739130       23
# Aquatic Toxicology                                         0.695652       23
# ...                                                             ...      ...
# Fundamental and Applied Toxicology                         1.000000        1
# Frontiers in public health                                 0.000000        1
# Food Additives & Contaminants: Part B                      1.000000        1
# European Journal of Surgical Oncology                      1.000000        1
# bioRxiv                                                    0.000000        1
#
# [166 rows x 2 columns]

# %%
Impact_F_Publishing_Year = data.Impact_F_Publishing_Year.mean()

outcomes_by_Journal.sort_values(Impact_F_Publishing_Year, ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-de300a4792c3> in <module>
# ----> 1 Impact_F_Publishing_Year = data.Impact_F_Publishing_Year.mean()
#       2
#       3 outcomes_by_Journal.sort_values(Impact_F_Publishing_Year, ascending = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
# ...

# %%
for journal in journals:
    fig, ax = plt.subplots(figsize =(10,10))
    other_journals = [c for c in journals if c != journal]
    data.groupby("Year").mean()["General_outcome"].plot.line(color = "k", linewidth = 2, alpha = .3, ax = ax)
    data[data[journal] == 1].groupby("Year").mean()["General_outcome"].plot.line(linewidth = 2, ax = ax)
    


    for c in other_journals:
        data[data[c] == 1].groupby("Year").mean()["General_outcome"].plot.line(ls = " ", marker = ".", markersize = 5, linewidth = 2, color = "k", alpha = .2, ax = ax)
    plt.title(journal)
    plt.show()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Food and Chemical Toxicology'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-eb1738202fa1> in <module>
# ...

# %%
outcomes_by_Institution = data.groupby("Institution").mean()[["General_outcome"]]
outcomes_by_Institution["num_obs"] = data["Institution"].value_counts()

outcomes_by_Institution.sort_values("num_obs", ascending = False)
# Out:
#                                 General_outcome  num_obs
# Institution
# University                             0.778068      383
# Public                                 0.611111       54
# Public & University                    0.674419       43
# Private                                0.272727       11
# Private & University                   0.250000        8
# Private & Public                       0.500000        2
# International Org                      0.000000        1
# University & International Org         1.000000        1

# %%
institutions = list(set(data["Institution"]))

# %%
for institution in institutions:
    fig, ax = plt.subplots(figsize =(10,10))
    other_institution = [c for c in institutions if c != institution]
    data.groupby("Year").mean()["General_outcome"].plot.line(color = "k", linewidth = 2, alpha = .3, ax = ax)
    data[data[institution] == 1].groupby("Year").mean()["General_outcome"].plot.line(linewidth = 2, ax = ax)
    


    for c in other_institution:
        data[data[c] == 1].groupby("Year").mean()["General_outcome"].plot.line(ls = " ", marker = ".", markersize = 5, linewidth = 2, color = "k", alpha = .2, ax = ax)
    plt.title(institution)
    plt.show()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'University '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-65f2b8536a55> in <module>
#       8
# ...
